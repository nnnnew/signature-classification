# %% [markdown]
# # Import modules

# %%
import tensorflow as tf
import tensorflow.keras as keras
from keras import backend as K
from keras.models import Sequential
from keras.layers import Activation
from keras.layers.core import Dense, Flatten
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import *

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

import itertools
import numpy as np
from matplotlib import pyplot as plt
import cv2
import sys, os, glob
import h5py
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Define params and helpers

# %%
images_size = 224

# Train image and train label define variable
train_image_path = 'train_images.h5'
train_label_path = 'train_labels.h5'
train_image_key = 'NISDCC-offline'
train_label_key = 'NISDCC-offline-labels'

# %% [markdown]
# # Read images and labels

# %%
with h5py.File(train_image_path, 'r') as hf:
    x = hf[train_image_key][:]

# %%
with h5py.File(train_label_path, 'r') as hf:
    y = hf[train_label_key][:]
    y = train_labels-1

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x[i], cmap='gray')
    plt.xlabel(y[i])

# %% [markdown]
# # Split train and test

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

# %%
print('Num of x_train is ' + str(len(x_train)))
print('Num of x_test is ' + str(len(x_test)))
# Out:
# Num of x_train is 1518
# Num of x_test is 380

# %% [markdown]
# # Data Augmentation
# ## Mixup

# %% [markdown]
# ## Rotation

# %% [markdown]
# ## Gussian blur

# %% [markdown]
# train_images = np.random.permutation.uniform(train_images)
